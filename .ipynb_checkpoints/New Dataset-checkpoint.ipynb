# %%
import pandas as pd

# %%
file = pd.read_table('New Dataset/Counts.txt', sep = ',')

# %%
file = file.set_index('ID')

# %%
file['Time']
# Out:
# ID
# 15403_12_1558061203352552595    521410813
# 15403_12_1558061203873994946     27516232
# 15403_12_1558061203901555711     23520299
# 15403_12_1558061203925100262     36100865
# 15403_12_1558061203961228441     22189918
#                                   ...
# 15665_12_1558061454661536498     75992870
# 15665_12_1558061454737548277    169693740
# 15665_12_1558061454941224796     49176505
# 15665_12_1558061455010255909     33428804
# 15665_12_1558061455043721147    116936877
# Name: Time, Length: 16124, dtype: int64

# %%
file['Time'][0]
# Out:
# 521410813

# %%
request_time = {}

for i in range(16124):
    request_time[file.index[i]] = file['Time'][i]

# %%
request_time
# Out:
# {'15403_12_1558061203352552595': 521410813,
#  '15403_12_1558061203873994946': 27516232,
#  '15403_12_1558061203901555711': 23520299,
#  '15403_12_1558061203925100262': 36100865,
#  '15403_12_1558061203961228441': 22189918,
#  '15403_12_1558061203983441272': 26907195,
#  '15403_12_1558061204010370385': 20814824,
#  '15403_12_1558061204031224371': 35008705,
#  '15403_12_1558061204066259167': 30066342,
#  '15403_12_1558061204096387629': 32692533,
#  '15403_12_1558061204129111643': 34752701,
#  '15403_12_1558061204163888423': 22427779,
#  '15403_12_1558061204186340282': 35241620,
#  '15403_12_1558061204221618474': 29946970,
#  '15403_12_1558061204251609093': 26252478,
#  '15403_12_1558061204277883016': 28054821,
#  '15403_12_1558061204305987029': 27312614,
#  '15403_12_1558061204333321240': 34228111,
#  '15403_12_1558061204367586664': 39188762,
#  '15403_12_1558061204406803920': 36026790,
#  '15403_12_1558061204442853867': 43994107,
#  '15403_12_1558061204486873926': 44047741,
# ...

# %%
filename = "New Dataset/sys_calls.txt"
request = []

with open(filename, 'r') as filehandle:
    for line in filehandle:
        request.append(line)
        break
